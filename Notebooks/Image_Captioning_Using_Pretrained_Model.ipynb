# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-to-text", model="nlpconnect/vit-gpt2-image-captioning")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Use a pipeline as a high-level helper
# ----> 2 from transformers import pipeline
#       4 pipe = pipeline("image-to-text", model="nlpconnect/vit-gpt2-image-captioning")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
from transformers import AutoTokenizer, AutoModelForImageTextToText
tokenizer = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
model = AutoModelForImageTextToText.from_pretrained("nlpconnect/vit-gpt2-image-captioning").to(device)
image_processor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

# %%
import torch
from PIL import Image
from transformers import VisionEncoderDecoderModel, ViTImageProcessor, GPT2TokenizerFast
from tqdm import tqdm

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
def get_caption(model, image_processor, tokenizer, image_path):
    image = load_image(image_path)

    img = image_processor(image, return_tensors="pt").to(device)

    output = model.generate(**img)

    caption = tokenizer.batch_decode(output, skip_special_tokens=True)[0]

    return caption

# %%
import os
def load_image(image_path):
  if os.path.exists(image_path):
        return Image.open(image_path)
  else:
    return 'Enter Valid Path'

# %%
from IPython.display import display

# %%
image_path = '/content/10815824_2997e03d76.jpg'
display(load_image(image_path))
caption = get_caption(model,image_processor,tokenizer,image_path)
print('Caption of the Image: ',caption)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>
# Caption of the Image:  a man is holding a hose to a horse

# %%
image_path = '/content/667626_18933d713e.jpg'
display(load_image(image_path))
caption = get_caption(model,image_processor,tokenizer,image_path)
print('Caption of the Image: ',caption)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>
# Caption of the Image:  a woman in a bikini on a beach

# %%
image_path = '/content/36422830_55c844bc2d.jpg'
display(load_image(image_path))
caption = get_caption(model,image_processor,tokenizer,image_path)
print('Caption of the Image: ',caption)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>
# Caption of the Image:  a red and white truck with a person on it

# %%
 image_path = '/content/_a12e9e18-9956-4e8e-8466-ecec4557c2c6.jpeg'
display(load_image(image_path))
caption = get_caption(model,image_processor,tokenizer,image_path)
print('Caption of the Image: ',caption)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>
# Caption of the Image:  a woman and a man riding on a motorcycle
